# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

# Suppress warnings to improve code readability (optional)
warnings.filterwarnings("ignore")

# %%
# Read the cleaned and preprocessed data from 'cricket.csv' into a DataFrame 'df'
df = pd.read_csv('cricket2.csv')

# %%
df.head()
# Out:
#    player_id      player_name  runs_scored  wickets  runs_conceded  catches  \
# 0          4      Virat Kohli           28        0             16        0
# 1         14     Ishan Kishan           33        0              0        0
# 2         20       Haris Rauf            0        0             57        2
# 3         25  Mohammad Rizwan           34        0              0        1
# 4         12   Mohammed Shami            0        1             59        0
#
#    stumpings  match_date                   opposition  match_id  ...  TDNB  \
# 0          0  2010-06-24         v Sri Lanka Dambulla        50  ...     0
# 1          0  2023-09-12    v Sri Lanka Colombo (RPS)       248  ...     0
# 2          0  2022-03-31           v Australia Lahore       439  ...     0
# 3          0  2016-09-04            v England Cardiff       374  ...     0
# 4          0  2018-10-24  v West Indies Visakhapatnam       190  ...     0
#
#    year  years_of_experience  bowling_average  runs_scored_mean/yr  \
# 0  2010                   15       923.500000            39.800000
# 1  2023                    2         0.000000            27.266667
# 2  2022                    3        24.320755             1.000000
# 3  2016                    8         0.000000            12.833333
# 4  2018                   10        25.427746             0.000000
#
#    wickets_mean/yr  runs_scored_mean/opp  wickets_mean/opp  mean_runs_scored  \
# 0         0.000000             29.428571          0.000000         46.558719
# 1         0.000000             29.000000          0.000000         35.440000
# 2         2.142857              2.333333          1.666667          0.535714
# 3         0.000000             23.500000          0.000000         26.046154
# 4         1.500000              0.000000          2.000000          2.234043
#
#    mean_wicket
# 0     0.014235
# 1     0.000000
# 2     1.892857
# 3     0.000000
# 4     1.840426
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2021 entries, 0 to 2020
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   player_id                     2021 non-null   int64
#  1   player_name                   2021 non-null   object
#  2   runs_scored                   2021 non-null   int64
#  3   wickets                       2021 non-null   int64
#  4   runs_conceded                 2021 non-null   int64
#  5   catches                       2021 non-null   int64
#  6   stumpings                     2021 non-null   int64
#  7   match_date                    2021 non-null   object
#  8   opposition                    2021 non-null   object
#  9   match_id                      2021 non-null   int64
#  10  avg_runs_scored_last7matches  2021 non-null   float64
#  11  DNB                           2021 non-null   int64
#  12  TDNB                          2021 non-null   int64
#  13  year                          2021 non-null   int64
#  14  years_of_experience           2021 non-null   int64
#  15  bowling_average               2021 non-null   float64
#  16  runs_scored_mean/yr           2021 non-null   float64
#  17  wickets_mean/yr               2021 non-null   float64
#  18  runs_scored_mean/opp          2021 non-null   float64
#  19  wickets_mean/opp              2021 non-null   float64
#  20  mean_runs_scored              2021 non-null   float64
#  21  mean_wicket                   2021 non-null   float64
# dtypes: float64(8), int64(11), object(3)
# memory usage: 347.5+ KB

# %%
# Create a new DataFrame 'new_df' by dropping columns 'player_name', 'match_date', and 'opposition' from 'df'
new_df = df.drop(['player_name','match_date','opposition'], axis=1)

# %%
#new_df = pd.get_dummies(new_df, columns=['opposition'], drop_first=True)

# %%
new_df.head()
# Out:
#    player_id  runs_scored  wickets  runs_conceded  catches  stumpings  \
# 0          4           28        0             16        0          0
# 1         14           33        0              0        0          0
# 2         20            0        0             57        2          0
# 3         25           34        0              0        1          0
# 4         12            0        1             59        0          0
#
#    match_id  avg_runs_scored_last7matches  DNB  TDNB  year  \
# 0        50                     39.142857    0     0  2010
# 1       248                     38.428571    0     0  2023
# 2       439                      1.857143    1     0  2022
# 3       374                     40.714286    0     0  2016
# 4       190                      7.142857    0     0  2018
#
#    years_of_experience  bowling_average  runs_scored_mean/yr  wickets_mean/yr  \
# 0                   15       923.500000            39.800000         0.000000
# 1                    2         0.000000            27.266667         0.000000
# 2                    3        24.320755             1.000000         2.142857
# 3                    8         0.000000            12.833333         0.000000
# 4                   10        25.427746             0.000000         1.500000
#
#    runs_scored_mean/opp  wickets_mean/opp  mean_runs_scored  mean_wicket
# 0             29.428571          0.000000         46.558719     0.014235
# 1             29.000000          0.000000         35.440000     0.000000
# 2              2.333333          1.666667          0.535714     1.892857
# 3             23.500000          0.000000         26.046154     0.000000
# 4              0.000000          2.000000          2.234043     1.840426

# %%
# Create the feature matrix 'X' by dropping the 'wickets' column from 'new_df'
X = new_df.drop('runs_scored', axis=1)

# %%
# Create the target variable 'y' by selecting the 'wickets' column from 'new_df'
y = new_df['runs_scored']

# %%
# Import required libraries and modules for machine learning
from sklearn.model_selection import train_test_split, GridSearchCV
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error

# %%
X.head()
# Out:
#    player_id  wickets  runs_conceded  catches  stumpings  match_id  \
# 0          4        0             16        0          0        50
# 1         14        0              0        0          0       248
# 2         20        0             57        2          0       439
# 3         25        0              0        1          0       374
# 4         12        1             59        0          0       190
#
#    avg_runs_scored_last7matches  DNB  TDNB  year  years_of_experience  \
# 0                     39.142857    0     0  2010                   15
# 1                     38.428571    0     0  2023                    2
# 2                      1.857143    1     0  2022                    3
# 3                     40.714286    0     0  2016                    8
# 4                      7.142857    0     0  2018                   10
#
#    bowling_average  runs_scored_mean/yr  wickets_mean/yr  \
# 0       923.500000            39.800000         0.000000
# 1         0.000000            27.266667         0.000000
# 2        24.320755             1.000000         2.142857
# 3         0.000000            12.833333         0.000000
# 4        25.427746             0.000000         1.500000
#
#    runs_scored_mean/opp  wickets_mean/opp  mean_runs_scored  mean_wicket
# 0             29.428571          0.000000         46.558719     0.014235
# 1             29.000000          0.000000         35.440000     0.000000
# 2              2.333333          1.666667          0.535714     1.892857
# 3             23.500000          0.000000         26.046154     0.000000
# 4              0.000000          2.000000          2.234043     1.840426

# %%
# Split the data into training and testing sets
# X_train and y_train will be used for training the model
# X_test and y_test will be used for evaluating the model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_train
# Out:
#       player_id  wickets  runs_conceded  catches  stumpings  match_id  \
# 1763          6        0              0        0          1       344
# 289           4        0             13        0          0       286
# 1668         13        2             42        0          0       314
# 534          15        0              0        0          0       243
# 806           1        0             18        1          0       246
# ...         ...      ...            ...      ...        ...       ...
# 1130          4        0             26        0          0        90
# 1294          4        0             13        0          0       117
# 860          27        0             29        0          0       458
# 1459          4        0             13        0          0       299
# 1126          1        0             23        0          0        85
#
#       avg_runs_scored_last7matches  DNB  TDNB  year  years_of_experience  \
# 1763                     48.142857    0     0  2020                    7
# 289                      39.142857    0     0  2009                   15
# 1668                      7.714286    0     0  2011                   13
# 534                      33.428571    0     0  2023                    2
# 806                      41.000000    0     0  2023                   16
# ...                            ...  ...   ...   ...                  ...
# 1130                     39.142857    0     0  2013                   15
# 1294                     39.142857    0     0  2014                   15
# 860                      22.285714    0     0  2023                    1
# 1459                     39.142857    1     0  2010                   15
# 1126                     41.000000    0     0  2012                   16
#
#       bowling_average  runs_scored_mean/yr  wickets_mean/yr  \
# 1763         0.000000            49.222222         0.000000
# 289        923.500000            32.500000         0.000000
# 1668        32.955975             6.777778         1.500000
# 534          0.000000            20.214286         0.000000
# 806        543.625000            41.125000         0.000000
# ...               ...                  ...              ...
# 1130       923.500000            37.294118         0.029412
# 1294       923.500000            50.190476         0.047619
# 860        124.500000            22.333333         0.266667
# 1459       923.500000            39.800000         0.000000
# 1126       543.625000            12.000000         0.142857
#
#       runs_scored_mean/opp  wickets_mean/opp  mean_runs_scored  mean_wicket
# 1763             88.000000               0.0         37.557377     0.000000
# 289              79.000000               0.0         46.558719     0.014235
# 1668              1.000000               2.0          6.147826     1.382609
# 534               0.000000               0.0         22.233333     0.000000
# 806              74.000000               0.0         40.286853     0.031873
# ...                    ...               ...               ...          ...
# 1130             22.000000               0.0         46.558719     0.014235
# 1294             10.500000               0.0         46.558719     0.014235
# 860               5.000000               0.0         24.222222     0.222222
# 1459              0.000000               0.0         46.558719     0.014235
# 1126             60.666667               0.0         40.286853     0.031873
#
# [1818 rows x 18 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import mean_squared_error, r2_score

# Define your model architecture
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)  # Output layer with 1 neuron for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
model.fit(scaled_X_train, y_train, epochs=60, batch_size=32, validation_split=0.2)

# Make predictions
predictions = model.predict(scaled_X_test)

# Calculate R-squared (R2) score
r2 = r2_score(y_test, predictions)

# Print the R2 score
print("R-squared (R2) Score:", r2)
# Out:
# Epoch 1/60
# 46/46 [==============================] - 4s 10ms/step - loss: 1873.7048 - mae: 25.0784 - val_loss: 1597.0908 - val_mae: 23.8967
# Epoch 2/60
# 46/46 [==============================] - 0s 5ms/step - loss: 1292.0411 - mae: 21.2343 - val_loss: 839.4913 - val_mae: 19.3584
# Epoch 3/60
# 46/46 [==============================] - 0s 5ms/step - loss: 779.2456 - mae: 18.8754 - val_loss: 649.5246 - val_mae: 18.2714
# Epoch 4/60
# 46/46 [==============================] - 0s 4ms/step - loss: 642.1635 - mae: 17.4138 - val_loss: 551.8320 - val_mae: 16.7828
# Epoch 5/60
# 46/46 [==============================] - 0s 5ms/step - loss: 526.2615 - mae: 15.4973 - val_loss: 442.1349 - val_mae: 14.6183
# Epoch 6/60
# 46/46 [==============================] - 0s 6ms/step - loss: 415.9727 - mae: 13.1692 - val_loss: 359.4619 - val_mae: 12.3705
# Epoch 7/60
# 46/46 [==============================] - 0s 4ms/step - loss: 351.9081 - mae: 11.4055 - val_loss: 323.7498 - val_mae: 11.2094
# Epoch 8/60
# 46/46 [==============================] - 0s 4ms/step - loss: 328.6771 - mae: 10.4714 - val_loss: 316.7250 - val_mae: 10.8265
# Epoch 9/60
# 46/46 [==============================] - 0s 5ms/step - loss: 323.2279 - mae: 10.2042 - val_loss: 312.0290 - val_mae: 10.5884
# Epoch 10/60
# 46/46 [==============================] - 0s 6ms/step - loss: 320.0523 - mae: 10.0693 - val_loss: 309.0387 - val_mae: 10.4575
# Epoch 11/60
# 46/46 [==============================] - 0s 6ms/step - loss: 316.5272 - mae: 9.9136 - val_loss: 307.5156 - val_mae: 10.4749
# Epoch 12/60
# 46/46 [==============================] - 0s 4ms/step - loss: 294.2560 - mae: 8.7305 - val_loss: 297.4325 - val_mae: 9.3829
# Epoch 56/60
# 46/46 [==============================] - 0s 4ms/step - loss: 292.5831 - mae: 8.7133 - val_loss: 296.0479 - val_mae: 9.3509
# Epoch 57/60
# 46/46 [==============================] - 0s 4ms/step - loss: 290.4669 - mae: 8.6374 - val_loss: 297.3487 - val_mae: 9.4173
# Epoch 58/60
# 46/46 [==============================] - 0s 4ms/step - loss: 298.6425 - mae: 8.8647 - val_loss: 299.4655 - val_mae: 9.5677
# Epoch 59/60
# 46/46 [==============================] - 0s 4ms/step - loss: 292.6606 - mae: 8.7096 - val_loss: 297.1548 - val_mae: 9.3612
# Epoch 60/60
# 46/46 [==============================] - 0s 3ms/step - loss: 291.5117 - mae: 8.6878 - val_loss: 297.5290 - val_mae: 9.4540
# 7/7 [==============================] - 0s 2ms/step
# R-squared (R2) Score: 0.7366654447774412

# %%
# Create a DataFrame to compare true and predicted values
comparison_df = pd.DataFrame({'true': y_test, 'pred': np.round(predictions.reshape(-1)).astype(int)})

# %%
# Add a new column 'wickets_pred' to the X_test DataFrame to store the predicted wicket values
X_test['runs_scored_pred'] = comparison_df['pred'].values

# %%
X_test.head()
# Out:
#       player_id  wickets  runs_conceded  catches  stumpings  match_id  \
# 674          17        0             54        0          0       187
# 1383         29        2             31        1          0       457
# 720           1        0             11        0          0        24
# 590           5        0              8        0          0       216
# 576          13        2             64        0          0       107
#
#       avg_runs_scored_last7matches  DNB  TDNB  year  years_of_experience  \
# 674                      16.714286    0     0  2018                    6
# 1383                      5.571429    0     0  2023                    5
# 720                      41.000000    0     0  2008                   16
# 590                      37.714286    0     1  2019                    6
# 576                       7.714286    1     0  2013                   13
#
#       bowling_average  runs_scored_mean/yr  wickets_mean/yr  \
# 674         33.188235            10.176471         1.411765
# 1383        23.363636             3.250000         2.000000
# 720        543.625000            19.000000         0.000000
# 590          0.000000            44.333333         0.000000
# 576         32.955975             5.758621         1.379310
#
#       runs_scored_mean/opp  wickets_mean/opp  mean_runs_scored  mean_wicket  \
# 674               9.000000               0.5         11.468750     1.328125
# 1383              2.000000               2.0          3.204545     2.000000
# 720              19.333333               0.0         40.286853     0.031873
# 590               0.000000               0.0         38.319149     0.000000
# 576               0.000000               2.0          6.147826     1.382609
#
#       runs_scored_pred
# 674                  8
# 1383                 3
# 720                 14
# 590                  0
# 576                  0

# %%
X_test['runs_scored'] =y_test

# %%
from scipy import stats

# Calculate the mean and mode of predictions for each player_id
mean_predictions = X_test.groupby('player_id')['runs_scored_pred'].mean()
mode_predictions = X_test.groupby('player_id')['runs_scored_pred'].apply(lambda x: stats.mode(x)[0][0])
mean_y_test = X_test.groupby('player_id')['runs_scored'].mean()
mode_y_test = X_test.groupby('player_id')['runs_scored'].apply(lambda x: stats.mode(x)[0][0])

# Create a DataFrame to store both mean and mode predictions
player_predictions = pd.DataFrame({
    'player_id': mean_predictions.index,
    'mean_prediction': np.round(mean_predictions.values).astype(int),
    'mode_prediction': mode_predictions.values,
    'mean_runs_scored': np.round(mean_y_test).astype(int),
    'mode_runs_scored': mode_y_test
})

# %%
player_predictions.tail()
# Out:
#            player_id  mean_prediction  mode_prediction  mean_runs_scored  \
# player_id
# 25                25               22               -3                22
# 26                26                2                0                 2
# 27                27               22               22                23
# 29                29                3                3                 2
# 30                30                1                1                 0
#
#            mode_runs_scored
# player_id
# 25                        0
# 26                        0
# 27                       23
# 29                        0
# 30                        0

# %%
mse = mean_squared_error(player_predictions['mean_runs_scored'], player_predictions['mean_prediction'])  # Calculate Mean Squared Error
r2 = r2_score(player_predictions['mean_runs_scored'], player_predictions['mean_prediction'])  # Calculate R-squared (coefficient of determination)

# Print the best hyperparameters and evaluation metrics
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 13.384615384615385
# R-squared: 0.9543843551647819

# %%
mse = mean_squared_error(player_predictions['mode_runs_scored'], player_predictions['mode_prediction'])  # Calculate Mean Squared Error
r2 = r2_score(player_predictions['mode_runs_scored'], player_predictions['mode_prediction'])  # Calculate R-squared (coefficient of determination)

# Print the best hyperparameters and evaluation metrics
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 154.65384615384616
# R-squared: -4.9850011449507665

# %%
runs_predd = player_predictions[['mean_prediction']]

# %%
runs_predd = runs_predd.reset_index()

# %%
runs_predd
# Out:
#     player_id  mean_prediction
# 0           1               35
# 1           2               12
# 2           3               54
# 3           4               38
# 4           5               38
# 5           6               47
# 6           7               11
# 7           8               31
# 8           9                1
# 9          10                0
# 10         11                3
# 11         12                4
# 12         13                7
# 13         14               24
# 14         16               37
# 15         17               17
# 16         19               35
# 17         20                3
# 18         21                3
# 19         22               26
# 20         23               43
# 21         25               22
# 22         26                2
# 23         27               22
# 24         29                3
# 25         30                1

# %%
 X_test[X_test['player_id'] == 18]
# Out:
# Empty DataFrame
# Columns: [player_id, wickets, runs_conceded, catches, stumpings, match_id, avg_runs_scored_last7matches, DNB, TDNB, year, years_of_experience, bowling_average, runs_scored_mean/yr, wickets_mean/yr, runs_scored_mean/opp, wickets_mean/opp, mean_runs_scored, mean_wicket, runs_scored_pred, runs_scored]
# Index: []

# %%
id_15 = X_train[X_train['player_id'] == 15]
id_24 = X_train[X_train['player_id'] == 24]
id_28 = X_train[X_train['player_id'] == 28]
id_18 = X_train[X_train['player_id'] == 18]

# %%
# Make predictions using the trained XGBoost regressor
id15_pred = np.round(model.predict(scaler.transform(id_15))).astype(int)
id18_pred = np.round(model.predict(scaler.transform(id_18))).astype(int)
id24_pred = np.round(model.predict(scaler.transform(id_24))).astype(int)
id28_pred = np.round(model.predict(scaler.transform(id_28))).astype(int)

print(id15_pred)
print(id18_pred)
print(id24_pred)
print(id28_pred)

# Calculate the mean for each of the four indices and round to the nearest integer
mean_id15_pred = int(round(id15_pred.mean()))
mean_id18_pred = int(round(id18_pred.mean()))
mean_id24_pred = int(round(id24_pred.mean()))
mean_id28_pred = int(round(id28_pred.mean()))

# Print the rounded means
print("Mean of id15_pred (rounded):", mean_id15_pred)
print("Mean of id18_pred (rounded):", mean_id18_pred)
print("Mean of id24_pred (rounded):", mean_id24_pred)
print("Mean of id28_pred (rounded):", mean_id28_pred)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# [[ 3]
#  [-1]
#  [30]
#  [ 7]
#  [22]
#  [10]
#  [34]
#  [45]
#  [10]
#  [48]
#  [ 5]
#  [ 9]
#  [26]
#  [37]
#  [ 4]
#  [45]
#  [-1]
#  [70]
#  [27]
#  [45]
#  [37]
#  [39]
#  [ 3]
#  [33]
#  [22]
#  [34]
#  [ 3]
#  [15]
#  [10]
#  [14]]
# [[57]
#  [ 9]
#  [11]
#  [25]]
# [[ 0]
#  [ 4]
#  [ 6]
#  [ 0]
#  [ 0]
#  [14]
#  [ 7]
#  [ 1]
#  [ 3]
#  [37]
#  [ 9]
#  [ 5]
#  [ 7]
#  [ 0]
#  [12]
#  [12]
#  [19]
#  [55]
#  [24]
#  [10]
#  [ 3]
#  [ 5]
#  [13]
#  [ 7]
#  [ 1]
#  [ 9]
#  [17]
#  [ 8]
#  [-1]
#  [ 7]
#  [ 0]
#  [28]]
# [[13]
#  [-2]
#  [ 5]
#  [ 8]
#  [ 9]
#  [56]]
# Mean of id15_pred (rounded): 23
# Mean of id18_pred (rounded): 26
# Mean of id24_pred (rounded): 10
# Mean of id28_pred (rounded): 15

# %%
missing_id = pd.DataFrame({'player_id':[15 ,18 ,24 ,28], 'mean_prediction':[23, 26, 10, 15]})

# %%
missing_id
# Out:
#    player_id  mean_prediction
# 0         15               23
# 1         18               26
# 2         24               10
# 3         28               15

# %%
runs_predd = pd.concat([runs_predd, missing_id], ignore_index=True).sort_values(by='player_id').reset_index()

# %%
runs_predd = runs_predd.drop('index',axis=1)

# %%
runs_predd
# Out:
#     player_id  mean_prediction
# 0           1               35
# 1           2               12
# 2           3               54
# 3           4               38
# 4           5               38
# 5           6               47
# 6           7               11
# 7           8               31
# 8           9                1
# 9          10                0
# 10         11                3
# 11         12                4
# 12         13                7
# 13         14               24
# 14         15               23
# 15         16               37
# 16         17               17
# 17         18               26
# 18         19               35
# 19         20                3
# 20         21                3
# 21         22               26
# 22         23               43
# 23         24               10
# 24         25               22
# 25         26                2
# 26         27               22
# 27         28               15
# 28         29                3
# 29         30                1

# %%
# Read the sample submission CSV file into a Pandas DataFrame
subm = pd.read_csv('cricket_predictionstf.csv')

# %%
subm.head()
# Out:
#    player_id  runs  wickets
# 0          1    30        0
# 1          2    24        1
# 2          3    45        0
# 3          4     5        0
# 4          5     9        0

# %%
runs_predd['mean_prediction'].shape
# Out:
# (30,)

# %%
# Assign the predicted wickets values to the 'wickets' column in the submission DataFrame
subm['runs'] = runs_predd['mean_prediction']

# %%
subm.isnull().sum()
# Out:
# player_id    0
# runs         0
# wickets      0
# dtype: int64

# %%
subm.head()
# Out:
#    player_id  runs  wickets
# 0          1    35        0
# 1          2    12        1
# 2          3    54        0
# 3          4    38        0
# 4          5    38        0

# %%
# Save the submission DataFrame to a CSV file
subm.to_csv('cricket_predictionstf.csv', index=False)

# %%
pd.read_csv('cricket_predictionstf.csv')
# Out:
#     player_id  runs  wickets
# 0           1    35        0
# 1           2    12        1
# 2           3    54        0
# 3           4    38        0
# 4           5    38        0
# 5           6    47        0
# 6           7    11        1
# 7           8    31        1
# 8           9     1        2
# 9          10     0        2
# 10         11     3        2
# 11         12     4        3
# 12         13     7        1
# 13         14    24        0
# 14         15    23        0
# 15         16    37        0
# 16         17    17        1
# 17         18    26        0
# 18         19    35        0
# 19         20     3        0
# 20         21     3        0
# 21         22    26        0
# 22         23    43        0
# 23         24    10        1
# 24         25    22        0
# 25         26     2        1
# 26         27    22        0
# 27         28    15        0
# 28         29     3        1
# 29         30     1        2
